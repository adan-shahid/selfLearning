# %%
import nltk
nltk.download()
# Out:
# showing info https://raw.githubusercontent.com/nltk/nltk_data/gh-pages/index.xml
# Exception in Tkinter callback
# Traceback (most recent call last):
#   File "C:\Users\Adan Shahid\AppData\Local\Programs\Python\Python313\Lib\tkinter\__init__.py", line 2079, in __call__
#     return self.func(*args)
#            ~~~~~~~~~^^^^^^^
#   File "C:\Users\Adan Shahid\AppData\Local\Programs\Python\Python313\Lib\tkinter\__init__.py", line 862, in callit
#     func(*args)
#     ~~~~^^^^^^^
#   File "c:\Users\Adan Shahid\Desktop\selfLearning\learning_env\Lib\site-packages\nltk\downloader.py", line 2226, in _monitor_message_queue
#     self._select(msg.package.id)
#                  ^^^^^^^^^^^^^^
# AttributeError: 'str' object has no attribute 'id'
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[2], line 2
#       1 import nltk
# ----> 2 nltk.download()
#
# ...
